# %%
import os, itertools, glob

import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib.ticker import MultipleLocator
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.transforms import ScaledTranslation

plt.rcParams['legend.handlelength'] = 1
plt.rcParams['legend.handleheight'] = 1.125
plt.rcParams["font.family"]         = "Avenir"
# mpl.rcParams['pdf.fonttype']        = 42

# mpl.rcParams.update({"pdf.use14corefonts": True})

path_to_images = '/Users/Guille/Desktop/india_power/images'
path_to_tables = '/Users/Guille/Desktop/india_power/tables'
path_to_data   = '/Users/Guille/Desktop/india_power/data/historic/year'

# %%
files_ = glob.glob(path_to_data + '//Electricity_Installed_Capacity*.xlsx')
print(path_to_data)

dfs_ = []
for file in files_:
    print(file)
    df_ = pd.read_excel(file, sheet_name = 'Electricity_Installed_Capacity')
    df_ = df_.loc[~(df_['Parameter'] == 'Total')]
    df_ = df_.drop(df_.index[-4:]).replace("-", 0)
    df_ = df_.drop(columns = ['STATE'])
    dfs_.append(df_)

dfs_ = pd.concat(dfs_, axis = 0)
dfs_.loc[dfs_.Parameter.str.contains('Solar'), 'Parameter'] = 'Solar (in MW)'
dfs_.loc[dfs_.Parameter.str.contains('Hydro'), 'Parameter'] = 'Hydro (in MW)'
dfs_.loc[dfs_.Parameter.str.contains('Bio-power'), 'Parameter'] = 'Biomass (in MW)'
dfs_ = dfs_.groupby(['Parameter']).agg('sum').reset_index(drop = False)
print(dfs_)
# Out:
# /Users/Guille/Desktop/india_power/data/historic/year
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039863532.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039719926.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039848669.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039756672.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039886775.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039693444.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039930060.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039906179.xlsx
# /Users/Guille/Desktop/india_power/data/historic/year/Electricity_Installed_Capacity_1748039816133.xlsx
# ...

# %%
print(dfs_.loc[5, '2022-23'])
print(dfs_.loc[5, '2023-24'])
print(dfs_.loc[5, '2023-24'] - dfs_.loc[5, '2022-23'])

print(dfs_.loc[6, '2022-23'])
print(dfs_.loc[6, '2023-24'])
print(dfs_.loc[6, '2023-24'] - dfs_.loc[6, '2022-23'])
# Out:
# 66735.35
# 81768.59
# 15033.23999999999
# 42628.83
# 45882.21
# 3253.3799999999974
